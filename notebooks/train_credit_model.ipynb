# %% [markdown]
# # Обучение модели кредитного скоринга
#
# Ноутбук запускает фиксированное обучение application-only pipeline. Исходный CSV берётся из пути `CREDIT_TRAIN_DATA_PATH` или из стандартного расположения проекта Home Credit.

# %%
# ruff: noqa: E402
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent
if not (ROOT / "scripts").exists():
    ROOT = Path.cwd().resolve()
sys.path.insert(0, str(ROOT))

from scripts.train_credit_model import main

main()
